# %% [markdown]
# ``` Categorical Plot ```:
# in this we plot categorical values
#
# ``` Types of plots ```:
# 1. boxplot
# 2. violinplot
# 3. stripplot
# 4. swarmplot
# 5. countplot
# 6. barplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
## Categorical plot
sns.catplot(x="day",y="total_bill",hue="sex",data=df,kind="bar")
plt.show()

# %%
## countplot
sns.countplot(x="sex",data=df,hue = "smoker")
plt.show()

# %%
## barplot
sns.barplot(x="day",y="total_bill",hue="sex",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## here data is divided by estimator
## we can set our own estimator
import numpy as np
sns.barplot(x="day",y="total_bill",hue="sex",data=df,estimator=np.sum)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
